# %% [markdown]
# # Iteratively re-weighted least squares (IRLS) compressed sensing algorithm
#
#
# Based on the archived [Julia V0.4](https://github.com/dahlend/CompressedSensing.jl) implentation of
# Equality constrained [Iteratively Reweighted Least Squares (IRLS) Lp Minimization.](https://www.sciencedirect.com/science/article/pii/S092523121300430X)
#
# A working Julia V1.1 implementation can also be found [here](https://github.com/tmellan/CompressedSensingJuliaV1).

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import inv

# %% [markdown]
# ### Make a sparse signal to test
# Uniform random distributed sparse signal, with normal intensities.

# %%
n=500  #Signal Dimensions
m=200  #Measurement Dimension
k=25;  #Approximate Sparsity

Signal = np.zeros(n)
RandIntSelection = (np.random.uniform(0,1,k)*(n-1)+np.ones(k)).astype(int)
Signal[RandIntSelection] = np.random.normal(0,1,k)
plt.plot(Signal)
plt.title('Test signal')
plt.xlabel('Signal component')
plt.ylabel('Signal intensity')
plt.show()

# %% [markdown]
# ### Create a Measurement of the signal with a random sensing function
# ##### Measurement = SensingFunction * Signal
# As a test case, the original sparse signal (k=25) will be recovered, using fewer measurements (m=200) than total components of the signal (n=500).
#
# Compressed sensing: "... with an overwhelming probability, any sparse signal with k nonzero components can be recovered from m ∼ k ln(n) random measurements, where n is the total number of sensing basis functions."

# %%
MM = np.random.uniform(0,1,[m,n]) #Random measurement matrix
Measurement = np.matmul(MM,Signal) #Measurement = MeasurementMatrix * Signal
plt.plot(Measurement)
plt.title('Measurement of signal with random sensing function')
plt.ylabel('Measured value')
plt.xlabel('Measurement component')
plt.show()

# %% [markdown]
# ### Confirm signal can't be recovered trivially from the undetermined system using standard methods (e.g. Moore-Penrose pseudoinverse)
# ##### Signal ≠ Pseudo-inverse (SensingFunction) * Measurement

# %%
#pinv from LinearAlgebra library
#Perfect recovery would give a straight line bisecting -- to ++. 
MM_moorepenrose_pinv  = np.linalg.pinv(MM)
moorePenrose_recovered_signal = np.matmul(MM_moorepenrose_pinv,Measurement)
plt.plot(moorePenrose_recovered_signal,Signal)
plt.scatter(moorePenrose_recovered_signal,Signal)
plt.title('Failed pinv signal recovery')
plt.ylabel('pinv recovered signal')
plt.xlabel('True signal')
plt.show()

# %% [markdown]
# ### IRLS algorithm to recover compressed sensing solution

# %%
##################
#Support functions
##################
def findSol(Y,A,M,Mt):
    return A-np.matmul(Mt,np.matmul(M,A)-Y)

def initSolution(MeasurementMatrix,MeasuredOutput,m):
    #Guess a random solution
    GuessedInput=np.zeros(m)
    GuessedInput[(np.random.uniform(0,1,round(m/10))*(m-1)+np.ones(round(m/10))).astype(int)] = np.random.uniform(0,1,round(m/10))

    #project the guessed solution into the space of exact answers
    GuessedInput=findSol(MeasuredOutput,
        GuessedInput,
        MeasurementMatrix,
        np.linalg.pinv(MeasurementMatrix))
    return GuessedInput

def plusOp(x):
    x.clip(min=0)

#function soft(x,l)
#    sign(x).*plusOp(abs(x)-l)
#end

#############################################
#Iteratively re-weighted least squares (IRLS)
#############################################
def IRLS(MeasurementMatrix,MeasuredOutput,verbose="false",maxiter=1000,p=.5,threshold=1e-7,debug="false"):

#Smooth
    eps=lambda eps : 1/eps**3
    
# identify the size of the input
    m=MeasurementMatrix.shape[1]
    
# First we need to calculate a valid solution
    GuessedInput = initSolution(MeasurementMatrix,MeasuredOutput,m)
    
###### Initialize some values used in the IRLS algorithm ############
#Construct the weight matrix, used in the ridge regression
    wn = np.zeros([m,m])
    
#Save a copy of the "previous" guess, which in this case is the original guess
    PrevGuess=GuessedInput

#transpose the sampling matrix, this is used every iteration so it
#is far more efficient to calculate it before hand.  
    tMeasurementMatrix=MeasurementMatrix.transpose()
    
#set the distance between iterations to infinite    
    PrevDist = np.full(round(maxiter/100 + 1), np.inf)
    
#start on iteration 1
    iteration=1
    if verbose == "true":
        print("Iteration: \n", iteration)
          
#assume we are converging, this will be set to false if neccessary
    converges="true"
    
    debugCounter = 0
    if debug == "true":
        print("\n 1."+str(debugCounter)+" Starting while loop")

    while PrevDist[round(iteration/100)] > threshold:
        
        debugCounter +=1

        if debug == "true":
            print("\n 1."+str(debugCounter)+" Starting for loop for wn")
            
        for j in range(0,m):
            wn[j,j] = 1. / (GuessedInput[j]**2  + eps(iteration))**(p/2. - 1.)
            
        if debug == "true":
            print("\n 2."+str(debugCounter)+" Ended for loop for wn")
        
        PrevGuess=GuessedInput
        
        if debug == "true":
            print("\n 3."+str(debugCounter)+" PrevGuess set as GuessInput\n Starting IRLS step")
    
#        #IRLS step
#        GuessedInput=wn*tMeasurementMatrix*
#        pinv(MeasurementMatrix*wn*tMeasurementMatrix)*
#        MeasuredOutput
            
        wntMeasurementMatrix = np.matmul(wn,tMeasurementMatrix)  
        MMwntMMpinv = np.linalg.pinv(np.matmul(MeasurementMatrix, wntMeasurementMatrix))  
        GuessedInput = np.matmul(wntMeasurementMatrix,np.matmul(MMwntMMpinv,MeasuredOutput))
        
        if debug == "true":
            print("\n 4."+str(debugCounter)+" Ending IRLS step")
       
        if iteration % (maxiter/100) == 1:
        
        #Measure Euclidean distance between answers  
            PrevDist[round(iteration/100)+1] = np.sqrt(np.sum(np.square(PrevGuess-GuessedInput)))/m
        
            if verbose == "true":
                print("\n"+str(iteration)+ "Euclidean Distance between steps: "+str(PrevDist[int(round(iteration/100)+1)]) )
        
        #most involved convergence test, see if the distance increases from one iteration
        #to the next, and if it does, break, converges=false since we didn't hit threshold
            if ((round(iteration/100)+1>2) and (PrevDist[round(iteration/100)+1] > PrevDist[max(round(iteration/100)+1,1)])):
                converges="false"
                break
            
        #if we pass maxiter iterations, give up
            if iteration>=maxiter:
                converges="false"
                break
            
        iteration+=1
            
    if verbose == "true":
        print("Completed Iteration: \n", iteration)
            
    #if debugging, return additional information, such as distance to convergence and iteration number
    if debug == "true":
        return (GuessedInput,converges,iteration-1,PrevDist[0:int(iteration/100)+1])
#       print(GuessedInput,converges,iteration-1,PrevDist[0:int(iteration/100)+1])
    else:
        return GuessedInput
#       print(GuessedInput)

# %% [markdown]
# ### Recover signal in debug mode

# %%
IRLS(MM,Measurement,verbose="true",maxiter=5000,p=.5,threshold=1e-7,debug="true")
# Out:
# Iteration:
#  1
#
#  1.0 Starting while loop
#
#  1.1 Starting for loop for wn
#
#  2.1 Ended for loop for wn
#
#  3.1 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.1 Ending IRLS step
#
# 1Euclidean Distance between steps: 0.0056710464727803885
#
#  1.2 Starting for loop for wn
#
#  2.2 Ended for loop for wn
#
#  3.2 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.2 Ending IRLS step
#
#  1.3 Starting for loop for wn
#
#  2.3 Ended for loop for wn
#
#  3.3 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.3 Ending IRLS step
#
#  1.4 Starting for loop for wn
#
#  2.4 Ended for loop for wn
#
#  3.4 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.4 Ending IRLS step
#
#  1.5 Starting for loop for wn
#
#  2.5 Ended for loop for wn
#
#  3.5 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.5 Ending IRLS step
#
#  1.6 Starting for loop for wn
#
#  2.6 Ended for loop for wn
#
#  3.6 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.6 Ending IRLS step
#
#  1.7 Starting for loop for wn
#
#  2.7 Ended for loop for wn
#
#  3.7 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.7 Ending IRLS step
#
#  1.8 Starting for loop for wn
#
#  2.8 Ended for loop for wn
#
#  3.8 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.8 Ending IRLS step
#
#  1.9 Starting for loop for wn
#
#  2.9 Ended for loop for wn
#
#  3.9 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.9 Ending IRLS step
#
#  1.10 Starting for loop for wn
#
#  2.10 Ended for loop for wn
#
#  3.10 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.10 Ending IRLS step
#
#  1.11 Starting for loop for wn
#
#  2.11 Ended for loop for wn
#
#  3.11 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.11 Ending IRLS step
#
#  1.12 Starting for loop for wn
#
#  2.12 Ended for loop for wn
#
#  3.12 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.12 Ending IRLS step
#
#  1.13 Starting for loop for wn
#
#  2.13 Ended for loop for wn
#
#  3.13 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.13 Ending IRLS step
#
#  1.14 Starting for loop for wn
#
#  2.14 Ended for loop for wn
#
#  3.14 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.14 Ending IRLS step
#
#  1.15 Starting for loop for wn
#
#  2.15 Ended for loop for wn
#
#  3.15 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.15 Ending IRLS step
#
#  1.16 Starting for loop for wn
#
#  2.16 Ended for loop for wn
#
#  3.16 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.16 Ending IRLS step
#
#  1.17 Starting for loop for wn
#
#  2.17 Ended for loop for wn
#
#  3.17 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.17 Ending IRLS step
#
#  1.18 Starting for loop for wn
#
#  2.18 Ended for loop for wn
#
#  3.18 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.18 Ending IRLS step
#
#  1.19 Starting for loop for wn
#
#  2.19 Ended for loop for wn
#
#  3.19 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.19 Ending IRLS step
#
#  1.20 Starting for loop for wn
#
#  2.20 Ended for loop for wn
#
#  3.20 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.20 Ending IRLS step
#
#  1.21 Starting for loop for wn
#
#  2.21 Ended for loop for wn
#
#  3.21 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.21 Ending IRLS step
#
#  1.22 Starting for loop for wn
#
#  2.22 Ended for loop for wn
#
#  3.22 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.22 Ending IRLS step
#
#  1.23 Starting for loop for wn
#
#  2.23 Ended for loop for wn
#
#  3.23 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.23 Ending IRLS step
#
#  1.24 Starting for loop for wn
#
#  2.24 Ended for loop for wn
#
#  3.24 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.24 Ending IRLS step
#
#  1.25 Starting for loop for wn
#
#  2.25 Ended for loop for wn
#
#  3.25 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.25 Ending IRLS step
#
#  1.26 Starting for loop for wn
#
#  2.26 Ended for loop for wn
#
#  3.26 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.26 Ending IRLS step
#
#  1.27 Starting for loop for wn
#
#  2.27 Ended for loop for wn
#
#  3.27 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.27 Ending IRLS step
#
#  1.28 Starting for loop for wn
#
#  2.28 Ended for loop for wn
#
#  3.28 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.28 Ending IRLS step
#
#  1.29 Starting for loop for wn
#
#  2.29 Ended for loop for wn
#
#  3.29 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.29 Ending IRLS step
#
#  1.30 Starting for loop for wn
#
#  2.30 Ended for loop for wn
#
#  3.30 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.30 Ending IRLS step
#
#  1.31 Starting for loop for wn
#
#  2.31 Ended for loop for wn
#
#  3.31 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.31 Ending IRLS step
#
#  1.32 Starting for loop for wn
#
#  2.32 Ended for loop for wn
#
#  3.32 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.32 Ending IRLS step
#
#  1.33 Starting for loop for wn
#
#  2.33 Ended for loop for wn
#
#  3.33 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.33 Ending IRLS step
#
#  1.34 Starting for loop for wn
#
#  2.34 Ended for loop for wn
#
#  3.34 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.34 Ending IRLS step
#
#  1.35 Starting for loop for wn
#
#  2.35 Ended for loop for wn
#
#  3.35 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.35 Ending IRLS step
#
#  1.36 Starting for loop for wn
#
#  2.36 Ended for loop for wn
#
#  3.36 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.36 Ending IRLS step
#
#  1.37 Starting for loop for wn
#
#  2.37 Ended for loop for wn
#
#  3.37 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.37 Ending IRLS step
#
#  1.38 Starting for loop for wn
#
#  2.38 Ended for loop for wn
#
#  3.38 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.38 Ending IRLS step
#
#  1.39 Starting for loop for wn
#
#  2.39 Ended for loop for wn
#
#  3.39 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.39 Ending IRLS step
#
#  1.40 Starting for loop for wn
#
#  2.40 Ended for loop for wn
#
#  3.40 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.40 Ending IRLS step
#
#  1.41 Starting for loop for wn
#
#  2.41 Ended for loop for wn
#
#  3.41 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.41 Ending IRLS step
#
#  1.42 Starting for loop for wn
#
#  2.42 Ended for loop for wn
#
#  3.42 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.42 Ending IRLS step
#
#  1.43 Starting for loop for wn
#
#  2.43 Ended for loop for wn
#
#  3.43 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.43 Ending IRLS step
#
#  1.44 Starting for loop for wn
#
#  2.44 Ended for loop for wn
#
#  3.44 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.44 Ending IRLS step
#
#  1.45 Starting for loop for wn
#
#  2.45 Ended for loop for wn
#
#  3.45 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.45 Ending IRLS step
#
#  1.46 Starting for loop for wn
#
#  2.46 Ended for loop for wn
#
#  3.46 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.46 Ending IRLS step
#
#  1.47 Starting for loop for wn
#
#  2.47 Ended for loop for wn
#
#  3.47 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.47 Ending IRLS step
#
#  1.48 Starting for loop for wn
#
#  2.48 Ended for loop for wn
#
#  3.48 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.48 Ending IRLS step
#
#  1.49 Starting for loop for wn
#
#  2.49 Ended for loop for wn
#
#  3.49 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.49 Ending IRLS step
#
#  1.50 Starting for loop for wn
#
#  2.50 Ended for loop for wn
#
#  3.50 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.50 Ending IRLS step
#
#  1.51 Starting for loop for wn
#
#  2.51 Ended for loop for wn
#
#  3.51 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.51 Ending IRLS step
#
# 51Euclidean Distance between steps: 4.6786204235766946e-07
#
#  1.52 Starting for loop for wn
#
#  2.52 Ended for loop for wn
#
#  3.52 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.52 Ending IRLS step
#
#  1.53 Starting for loop for wn
#
#  2.53 Ended for loop for wn
#
#  3.53 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.53 Ending IRLS step
#
#  1.54 Starting for loop for wn
#
#  2.54 Ended for loop for wn
#
#  3.54 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.54 Ending IRLS step
#
#  1.55 Starting for loop for wn
#
#  2.55 Ended for loop for wn
#
#  3.55 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.55 Ending IRLS step
#
#  1.56 Starting for loop for wn
#
#  2.56 Ended for loop for wn
#
#  3.56 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.56 Ending IRLS step
#
#  1.57 Starting for loop for wn
#
#  2.57 Ended for loop for wn
#
#  3.57 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.57 Ending IRLS step
#
#  1.58 Starting for loop for wn
#
#  2.58 Ended for loop for wn
#
#  3.58 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.58 Ending IRLS step
#
#  1.59 Starting for loop for wn
#
#  2.59 Ended for loop for wn
#
#  3.59 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.59 Ending IRLS step
#
#  1.60 Starting for loop for wn
#
#  2.60 Ended for loop for wn
#
#  3.60 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.60 Ending IRLS step
#
#  1.61 Starting for loop for wn
#
#  2.61 Ended for loop for wn
#
#  3.61 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.61 Ending IRLS step
#
#  1.62 Starting for loop for wn
#
#  2.62 Ended for loop for wn
#
#  3.62 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.62 Ending IRLS step
#
#  1.63 Starting for loop for wn
#
#  2.63 Ended for loop for wn
#
#  3.63 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.63 Ending IRLS step
#
#  1.64 Starting for loop for wn
#
#  2.64 Ended for loop for wn
#
#  3.64 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.64 Ending IRLS step
#
#  1.65 Starting for loop for wn
#
#  2.65 Ended for loop for wn
#
#  3.65 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.65 Ending IRLS step
#
#  1.66 Starting for loop for wn
#
#  2.66 Ended for loop for wn
#
#  3.66 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.66 Ending IRLS step
#
#  1.67 Starting for loop for wn
#
#  2.67 Ended for loop for wn
#
#  3.67 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.67 Ending IRLS step
#
#  1.68 Starting for loop for wn
#
#  2.68 Ended for loop for wn
#
#  3.68 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.68 Ending IRLS step
#
#  1.69 Starting for loop for wn
#
#  2.69 Ended for loop for wn
#
#  3.69 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.69 Ending IRLS step
#
#  1.70 Starting for loop for wn
#
#  2.70 Ended for loop for wn
#
#  3.70 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.70 Ending IRLS step
#
#  1.71 Starting for loop for wn
#
#  2.71 Ended for loop for wn
#
#  3.71 PrevGuess set as GuessInput
#  Starting IRLS step
#  4.71 Ending IRLS step
#
#  1.72 Starting for loop for wn
#
#  2.72 Ended for loop for wn
#
#  3.72 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.72 Ending IRLS step
#
#  1.73 Starting for loop for wn
#
#  2.73 Ended for loop for wn
#
#  3.73 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.73 Ending IRLS step
#
#  1.74 Starting for loop for wn
#
#  2.74 Ended for loop for wn
#
#  3.74 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.74 Ending IRLS step
#
#  1.75 Starting for loop for wn
#
#  2.75 Ended for loop for wn
#
#  3.75 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.75 Ending IRLS step
#
#  1.76 Starting for loop for wn
#
#  2.76 Ended for loop for wn
#
#  3.76 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.76 Ending IRLS step
#
#  1.77 Starting for loop for wn
#
#  2.77 Ended for loop for wn
#
#  3.77 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.77 Ending IRLS step
#
#  1.78 Starting for loop for wn
#
#  2.78 Ended for loop for wn
#
#  3.78 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.78 Ending IRLS step
#
#  1.79 Starting for loop for wn
#
#  2.79 Ended for loop for wn
#
#  3.79 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.79 Ending IRLS step
#
#  1.80 Starting for loop for wn
#
#  2.80 Ended for loop for wn
#
#  3.80 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.80 Ending IRLS step
#
#  1.81 Starting for loop for wn
#
#  2.81 Ended for loop for wn
#
#  3.81 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.81 Ending IRLS step
#
#  1.82 Starting for loop for wn
#
#  2.82 Ended for loop for wn
#
#  3.82 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.82 Ending IRLS step
#
#  1.83 Starting for loop for wn
#
#  2.83 Ended for loop for wn
#
#  3.83 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.83 Ending IRLS step
#
#  1.84 Starting for loop for wn
#
#  2.84 Ended for loop for wn
#
#  3.84 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.84 Ending IRLS step
#
#  1.85 Starting for loop for wn
#
#  2.85 Ended for loop for wn
#
#  3.85 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.85 Ending IRLS step
#
#  1.86 Starting for loop for wn
#
#  2.86 Ended for loop for wn
#
#  3.86 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.86 Ending IRLS step
#
#  1.87 Starting for loop for wn
#
#  2.87 Ended for loop for wn
#
#  3.87 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.87 Ending IRLS step
#
#  1.88 Starting for loop for wn
#
#  2.88 Ended for loop for wn
#
#  3.88 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.88 Ending IRLS step
#
#  1.89 Starting for loop for wn
#
#  2.89 Ended for loop for wn
#
#  3.89 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.89 Ending IRLS step
#
#  1.90 Starting for loop for wn
#
#  2.90 Ended for loop for wn
#
#  3.90 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.90 Ending IRLS step
#
#  1.91 Starting for loop for wn
#
#  2.91 Ended for loop for wn
#
#  3.91 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.91 Ending IRLS step
#
#  1.92 Starting for loop for wn
#
#  2.92 Ended for loop for wn
#
#  3.92 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.92 Ending IRLS step
#
#  1.93 Starting for loop for wn
#
#  2.93 Ended for loop for wn
#
#  3.93 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.93 Ending IRLS step
#
#  1.94 Starting for loop for wn
#
#  2.94 Ended for loop for wn
#
#  3.94 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.94 Ending IRLS step
#
#  1.95 Starting for loop for wn
#
#  2.95 Ended for loop for wn
#
#  3.95 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.95 Ending IRLS step
#
#  1.96 Starting for loop for wn
#
#  2.96 Ended for loop for wn
#
#  3.96 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.96 Ending IRLS step
#
#  1.97 Starting for loop for wn
#
#  2.97 Ended for loop for wn
#
#  3.97 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.97 Ending IRLS step
#
#  1.98 Starting for loop for wn
#
#  2.98 Ended for loop for wn
#
#  3.98 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.98 Ending IRLS step
#
#  1.99 Starting for loop for wn
#
#  2.99 Ended for loop for wn
#
#  3.99 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.99 Ending IRLS step
#
#  1.100 Starting for loop for wn
#
#  2.100 Ended for loop for wn
#
#  3.100 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.100 Ending IRLS step
#
#  1.101 Starting for loop for wn
#
#  2.101 Ended for loop for wn
#
#  3.101 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.101 Ending IRLS step
#
# 101Euclidean Distance between steps: 5.547963445867954e-08
#
#  1.102 Starting for loop for wn
#
#  2.102 Ended for loop for wn
#
#  3.102 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.102 Ending IRLS step
#
#  1.103 Starting for loop for wn
#
#  2.103 Ended for loop for wn
#
#  3.103 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.103 Ending IRLS step
#
#  1.104 Starting for loop for wn
#
#  2.104 Ended for loop for wn
#
#  3.104 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.104 Ending IRLS step
#
#  1.105 Starting for loop for wn
#
#  2.105 Ended for loop for wn
#
#  3.105 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.105 Ending IRLS step
#
#  1.106 Starting for loop for wn
#
#  2.106 Ended for loop for wn
#
#  3.106 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.106 Ending IRLS step
#
#  1.107 Starting for loop for wn
#
#  2.107 Ended for loop for wn
#
#  3.107 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.107 Ending IRLS step
#
#  1.108 Starting for loop for wn
#
#  2.108 Ended for loop for wn
#
#  3.108 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.108 Ending IRLS step
#
#  1.109 Starting for loop for wn
#
#  2.109 Ended for loop for wn
#
#  3.109 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.109 Ending IRLS step
#
#  1.110 Starting for loop for wn
#
#  2.110 Ended for loop for wn
#
#  3.110 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.110 Ending IRLS step
#
#  1.111 Starting for loop for wn
#
#  2.111 Ended for loop for wn
#
#  3.111 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.111 Ending IRLS step
#
#  1.112 Starting for loop for wn
#
#  2.112 Ended for loop for wn
#
#  3.112 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.112 Ending IRLS step
#
#  1.113 Starting for loop for wn
#
#  2.113 Ended for loop for wn
#
#  3.113 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.113 Ending IRLS step
#
#  1.114 Starting for loop for wn
#
#  2.114 Ended for loop for wn
#
#  3.114 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.114 Ending IRLS step
#
#  1.115 Starting for loop for wn
#
#  2.115 Ended for loop for wn
#
#  3.115 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.115 Ending IRLS step
#
#  1.116 Starting for loop for wn
#
#  2.116 Ended for loop for wn
#
#  3.116 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.116 Ending IRLS step
#
#  1.117 Starting for loop for wn
#
#  2.117 Ended for loop for wn
#
#  3.117 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.117 Ending IRLS step
#
#  1.118 Starting for loop for wn
#
#  2.118 Ended for loop for wn
#
#  3.118 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.118 Ending IRLS step
#
#  1.119 Starting for loop for wn
#
#  2.119 Ended for loop for wn
#
#  3.119 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.119 Ending IRLS step
#
#  1.120 Starting for loop for wn
#
#  2.120 Ended for loop for wn
#
#  3.120 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.120 Ending IRLS step
#
#  1.121 Starting for loop for wn
#
#  2.121 Ended for loop for wn
#
#  3.121 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.121 Ending IRLS step
#
#  1.122 Starting for loop for wn
#
#  2.122 Ended for loop for wn
#
#  3.122 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.122 Ending IRLS step
#
#  1.123 Starting for loop for wn
#
#  2.123 Ended for loop for wn
#
#  3.123 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.123 Ending IRLS step
#
#  1.124 Starting for loop for wn
#
#  2.124 Ended for loop for wn
#
#  3.124 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.124 Ending IRLS step
#
#  1.125 Starting for loop for wn
#
#  2.125 Ended for loop for wn
#
#  3.125 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.125 Ending IRLS step
#
#  1.126 Starting for loop for wn
#
#  2.126 Ended for loop for wn
#
#  3.126 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.126 Ending IRLS step
#
#  1.127 Starting for loop for wn
#
#  2.127 Ended for loop for wn
#
#  3.127 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.127 Ending IRLS step
#
#  1.128 Starting for loop for wn
#
#  2.128 Ended for loop for wn
#
#  3.128 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.128 Ending IRLS step
#
#  1.129 Starting for loop for wn
#
#  2.129 Ended for loop for wn
#
#  3.129 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.129 Ending IRLS step
#
#  1.130 Starting for loop for wn
#
#  2.130 Ended for loop for wn
#
#  3.130 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.130 Ending IRLS step
#
#  1.131 Starting for loop for wn
#
#  2.131 Ended for loop for wn
#
#  3.131 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.131 Ending IRLS step
#
#  1.132 Starting for loop for wn
#
#  2.132 Ended for loop for wn
#
#  3.132 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.132 Ending IRLS step
#
#  1.133 Starting for loop for wn
#
#  2.133 Ended for loop for wn
#
#  3.133 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.133 Ending IRLS step
#
#  1.134 Starting for loop for wn
#
#  2.134 Ended for loop for wn
#
#  3.134 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.134 Ending IRLS step
#
#  1.135 Starting for loop for wn
#
#  2.135 Ended for loop for wn
#
#  3.135 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.135 Ending IRLS step
#
#  1.136 Starting for loop for wn
#
#  2.136 Ended for loop for wn
#
#  3.136 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.136 Ending IRLS step
#
#  1.137 Starting for loop for wn
#
#  2.137 Ended for loop for wn
#
#  3.137 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.137 Ending IRLS step
#
#  1.138 Starting for loop for wn
#
#  2.138 Ended for loop for wn
#
#  3.138 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.138 Ending IRLS step
#
#  1.139 Starting for loop for wn
#
#  2.139 Ended for loop for wn
#
#  3.139 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.139 Ending IRLS step
#
#  1.140 Starting for loop for wn
#
#  2.140 Ended for loop for wn
#
#  3.140 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.140 Ending IRLS step
#
#  1.141 Starting for loop for wn
#
#  2.141 Ended for loop for wn
#
#  3.141 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.141 Ending IRLS step
#
#  1.142 Starting for loop for wn
#
#  2.142 Ended for loop for wn
#
#  3.142 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.142 Ending IRLS step
#
#  1.143 Starting for loop for wn
#
#  2.143 Ended for loop for wn
#
#  3.143 PrevGuess set as GuessInput
#  Starting IRLS step
#  4.143 Ending IRLS step
#
#  1.144 Starting for loop for wn
#
#  2.144 Ended for loop for wn
#
#  3.144 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.144 Ending IRLS step
#
#  1.145 Starting for loop for wn
#
#  2.145 Ended for loop for wn
#
#  3.145 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.145 Ending IRLS step
#
#  1.146 Starting for loop for wn
#
#  2.146 Ended for loop for wn
#
#  3.146 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.146 Ending IRLS step
#
#  1.147 Starting for loop for wn
#
#  2.147 Ended for loop for wn
#
#  3.147 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.147 Ending IRLS step
#
#  1.148 Starting for loop for wn
#
#  2.148 Ended for loop for wn
#
#  3.148 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.148 Ending IRLS step
#
#  1.149 Starting for loop for wn
#
#  2.149 Ended for loop for wn
#
#  3.149 PrevGuess set as GuessInput
#  Starting IRLS step
#
#  4.149 Ending IRLS step
# Completed Iteration:
#  150
# (array([ 1.08520330e-06, -3.79263543e-06,  2.94112719e-06, -1.49083696e-05,
#          2.32014939e-05, -1.44505501e-05, -2.26471424e-05, -3.26913277e-06,
#         -2.80881679e-06, -4.28129509e-06, -1.53436195e-05,  5.27161658e-06,
#         -9.25110406e-06,  6.76276685e-06,  1.05056100e-01, -6.55239887e-06,
#         -1.92785351e-05,  2.54333876e-05, -5.08764641e-06, -4.96750588e-06,
#         -1.51847530e-05,  2.52407343e-06, -2.56638224e-05, -7.02440947e-07,
#         -1.04469474e-05, -1.67089162e-05,  1.01425012e-05, -2.03826780e-05,
#         -1.65988876e-06,  4.33907971e-06, -1.20860863e-05,  1.21607570e-05,
#          1.68320854e-06, -1.91942925e-05, -2.99853595e-06, -7.42870310e-03,
#          2.22181304e-06, -2.42042847e-05,  3.51709185e-07, -3.99716388e-05,
#         -7.98933575e-07,  1.44622893e-06, -1.32378606e-05,  5.95509023e-06,
#          6.46236214e-07, -3.36042842e-05, -1.49828234e-06, -2.42911112e-05,
#         -6.60538480e-06, -1.02639014e-05, -6.99924245e-06,  9.55441006e-06,
#         -1.25273085e-05,  1.18249438e-05,  4.76242169e-07, -1.08118415e-05,
#         -1.51541128e-05,  1.46884018e-05,  1.25537234e-05, -1.66413836e-05,
#         -2.55658198e-06,  6.09321801e-06, -1.01167855e-06,  1.55541756e-07,
#          8.09132001e-06, -3.49833045e-06, -1.33968749e-06, -1.02913419e-05,
#         -1.80635506e-05,  9.05108478e-06, -1.58342939e-05,  1.12484902e-05,
#         -8.01839771e-06, -3.24815623e-05, -7.34443148e-06,  4.19251180e-06,
#         -7.95265333e-06,  9.62869118e-06, -3.52808212e-06, -1.18472889e-05]),
#  'true',
#  149,
#  array([       inf, 0.00567105]))

# %% [markdown]
# ### Recover signal and plot against original signal

# %%
recoveredSignal_IRLS = IRLS(MM,Measurement,verbose="true")
# Out:
# Iteration:
#  1
#
# 1Euclidean Distance between steps: 0.004982546567105879
#
# 11Euclidean Distance between steps: 5.721894535644055e-05
#
# 21Euclidean Distance between steps: 6.175351273315492e-06
#
# 31Euclidean Distance between steps: 1.6439666105291907e-06
#
# 41Euclidean Distance between steps: 7.66157482184434e-07
#
# 51Euclidean Distance between steps: 4.678620448300282e-07
#
# 61Euclidean Distance between steps: 2.97583176216792e-07
#
# 71Euclidean Distance between steps: 1.8171421406698087e-07
#
# 81Euclidean Distance between steps: 1.1653321250444488e-07
#
# 91Euclidean Distance between steps: 7.871020152007988e-08
#
# 101Euclidean Distance between steps: 5.547963729574401e-08
#
# 111Euclidean Distance between steps: 4.047972464195096e-08
#
# 121Euclidean Distance between steps: 3.038429474262473e-08
#
# 131Euclidean Distance between steps: 2.3351998671255918e-08
#
# 141Euclidean Distance between steps: 1.830986828179564e-08
# Completed Iteration:
#  150

# %%
plt.scatter(recoveredSignal_IRLS,Signal) #Perfect recovery would give a straight line bisecting -- to ++. 
plt.plot(recoveredSignal_IRLS,Signal)
plt.title('Compressed sensing signal recovery')
plt.ylabel('IRLS recovered signal')
plt.xlabel('True signal')
plt.show()
